# %% [markdown]
# <a href="https://colab.research.google.com/github/oskarkris/cluster_project/blob/main/BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/oskarkris/cluster_project/main/csvdata/savedrecs%20(1).csv')
for n in range(2,13):
  df_temp = pd.read_csv("https://raw.githubusercontent.com/oskarkris/cluster_project/main/csvdata/savedrecs%20("+str(n)+").csv")
  df = pd.concat([df, df_temp])

# %%
df
# Out:
#     Publication Type                                            Authors  \
# 0                  J                                      Timilsina, GR
# 1                  J             Dannevig, H; Hovelsrud, GK; Husabo, IA
# 2                  J  Pietrapertosa, F; Khokhlov, V; Salvia, M; Cosm...
# 3                  J         Groulx, M; Lewis, J; Lemieux, C; Dawson, J
# 4                  J                                       Schneider, T
# ..               ...                                                ...
# 845                J  Anguelovski, I; Irazabal-Zurita, C; Connolly, JJT
# 846                J  Raynor, EJ; Derner, JD; Hoover, DL; Parton, WJ...
# 847                J  Jabakhanji, SB; Arnold, SR; Aunan, K; Chersich...
# 848                J  Peck, AJ; Adams, SL; Armstrong, A; Bartlett, A...
# 849                J  Pagliano, L; Cattarin, G; Causone, F; Kindinis, A
#
#      Book Authors Book Editors Book Group Authors  \
# 0             NaN          NaN                NaN
# 1             NaN          NaN                NaN
# 2             NaN          NaN                NaN
# 3             NaN          NaN                NaN
# 4             NaN          NaN                NaN
# ..            ...          ...                ...
# 845           NaN          NaN                NaN
# 846           NaN          NaN                NaN
# 847           NaN          NaN                NaN
# 848           NaN          NaN                NaN
# 849           NaN          NaN                NaN
#
#                                      Author Full Names  \
# 0                                Timilsina, Govinda R.
# 1    Dannevig, Halvor; Hovelsrud, Grete K.; Husabo,...
# 2    Pietrapertosa, Filomena; Khokhlov, Valeriy; Sa...
# 3    Groulx, Mark; Lewis, John; Lemieux, Christophe...
# 4                                      Schneider, Tina
# ..                                                 ...
# 845  Anguelovski, Isabelle; Irazabal-Zurita, Clara;...
# 846  Raynor, Edward J.; Derner, Justin D.; Hoover, ...
# 847  Jabakhanji, Samira Barbara; Arnold, Stephen Ro...
# 848  Peck, Andrew J.; Adams, Stevie L.; Armstrong, ...
# 849  Pagliano, Lorenzo; Cattarin, Giulio; Causone, ...
#
#      Book Author Full Names Group Authors  \
# 0                       NaN           NaN
# 1                       NaN           NaN
# 2                       NaN           NaN
# 3                       NaN           NaN
# 4                       NaN           NaN
# ..                      ...           ...
# 845                     NaN           NaN
# 846                     NaN           NaN
# 847                     NaN           NaN
# 848                     NaN           NaN
# 849                     NaN           NaN
#
#                                          Article Title  \
# 0    Financing Climate Change Adaptation: Internati...
# 1    Driving the agenda for climate change adaptati...
# 2    Climate change adaptation policies and plans: ...
# 3    Place-based climate change adaptation: A criti...
# 4    Responsibility for private sector adaptation t...
# ..                                                 ...
# 845  Grabbed Urban Landscapes: Socio-spatial Tensio...
# 846  Large-scale and local climatic controls on lar...
# 847  Public Health Measures to Address the Impact o...
# 848  A new framework for flood adaptation: introduc...
# 849  Improved methods for the calorimetric determin...
#
#                                           Source Title  ...  \
# 0                                       SUSTAINABILITY  ...
# 1     ENVIRONMENT AND PLANNING C-GOVERNMENT AND POLICY  ...
# 2               RENEWABLE & SUSTAINABLE ENERGY REVIEWS  ...
# 3                         LANDSCAPE AND URBAN PLANNING  ...
# 4                                  ECOLOGY AND SOCIETY  ...
# ..                                                 ...  ...
# 845  INTERNATIONAL JOURNAL OF URBAN AND REGIONAL RE...  ...
# 846                            ECOLOGICAL APPLICATIONS  ...
# 847  INTERNATIONAL JOURNAL OF ENVIRONMENTAL RESEARC...  ...
# 848                                ECOLOGY AND SOCIETY  ...
# 849                               ENERGY AND BUILDINGS  ...
#
#                                   Web of Science Index  \
# 0    Science Citation Index Expanded (SCI-EXPANDED)...
# 1                 Social Science Citation Index (SSCI)
# 2    Science Citation Index Expanded (SCI-EXPANDED)...
# 3    Science Citation Index Expanded (SCI-EXPANDED)...
# 4    Science Citation Index Expanded (SCI-EXPANDED)...
# ..                                                 ...
# 845               Social Science Citation Index (SSCI)
# 846     Science Citation Index Expanded (SCI-EXPANDED)
# 847  Science Citation Index Expanded (SCI-EXPANDED)...
# 848  Science Citation Index Expanded (SCI-EXPANDED)...
# 849     Science Citation Index Expanded (SCI-EXPANDED)
#
#                                         Research Areas IDS Number   Pubmed Id  \
# 0    Science & Technology - Other Topics; Environme...      SZ3EC         NaN
# 1    Environmental Sciences & Ecology; Public Admin...      171VB         NaN
# 2    Science & Technology - Other Topics; Energy & ...      FO7SY         NaN
# 3    Environmental Sciences & Ecology; Geography; P...      AT6PK         NaN
# 4                     Environmental Sciences & Ecology      AK8XI         NaN
# ..                                                 ...        ...         ...
# 845    Geography; Public Administration; Urban Studies      HI2CX         NaN
# 846                   Environmental Sciences & Ecology      LB2XJ  31829472.0
# 847  Environmental Sciences & Ecology; Public, Envi...      5P6WQ  36294243.0
# 848                   Environmental Sciences & Ecology      5V1SS         NaN
# 849  Construction & Building Technology; Energy & F...      FJ7SQ         NaN
#
#     Open Access Designations Highly Cited Status Hot Paper Status  \
# 0                       gold                 NaN              NaN
# 1                        NaN                 NaN              NaN
# 2                        NaN                 NaN              NaN
# 3                        NaN                 NaN              NaN
# 4      gold, Green Published                 NaN              NaN
# ..                       ...                 ...              ...
# 845           Green Accepted                 NaN              NaN
# 846                      NaN                 NaN              NaN
# 847     gold, Green Accepted                 NaN              NaN
# 848                     gold                 NaN              NaN
# 849                      NaN                 NaN              NaN
#
#     Date of Export   UT (Unique WOS ID)               Web of Science Record
# 0       2023-03-25  WOS:000666451800001  View Full Record in Web of Science
# 1       2023-03-25  WOS:000320956800008  View Full Record in Web of Science
# 2       2023-03-25  WOS:000417078200110  View Full Record in Web of Science
# 3       2023-03-25  WOS:000345061100013  View Full Record in Web of Science
# 4       2023-03-25  WOS:000338711600014  View Full Record in Web of Science
# ..             ...                  ...                                 ...
# 845     2023-03-25  WOS:000456253500009  View Full Record in Web of Science
# 846     2023-03-25  WOS:000506491300001  View Full Record in Web of Science
# 847     2023-03-25  WOS:000873289500001  View Full Record in Web of Science
# 848     2023-03-25  WOS:000877017100001  View Full Record in Web of Science
# 849     2023-03-25  WOS:000412959600042  View Full Record in Web of Science
#
# [11850 rows x 72 columns]
